# %% [markdown]
# # Jak działa pod spodem.
#
# Codziennie o godzinie 10:00 czasu UTC (11/12 czasu polskiego) Heroku Scheduler wywołuje podaną komendę:
#
# ![Heroku Scheduler](attachment:heroku_scheduler.png)

# %% [markdown]
# Wywołuje on moduł **bot.tweet**.
